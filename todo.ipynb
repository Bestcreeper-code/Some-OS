# %% [markdown]
# -# try implementing system that stores process+ some stack to upper mem to allow mult processes without paging or reloc via moving the binary in the "home adress"(0x200000 rn)

# %% [markdown]
# maybe find a way to copy bl+os to disk

# %% [markdown]
# #### fricking fix the login.bin
